# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# !pip install xgboost
import xgboost as xgb
# !pip install -U imbalanced-learn
from imblearn.over_sampling import SMOTE

# %%
X_train_csv = pd.read_csv('X_train.csv')
y_train_csv = pd.read_csv('y_train.csv')
X_test_csv = pd.read_csv('X_test.csv')

data = pd.merge(X_train_csv, y_train_csv, right_on='Unnamed: 0', left_on='Unnamed: 0')
data.sort_values(by='Unnamed: 0', inplace=True)
data.drop(columns=['Unnamed: 0'], inplace=True)

X = data.drop('LeaveOrNot', axis=1)
y = data['LeaveOrNot']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0)

# %%
data.set_index("id", inplace=True)
data
# Out:
#       Education  JoiningYear       City  PaymentTier   Age  Gender  \
# id
# 0     Bachelors         2017  Bangalore            3   NaN     NaN
# 1     Bachelors         2013       Pune            1   NaN     NaN
# 4       Masters         2017       Pune            3  26.0    Male
# 5     Bachelors         2016  Bangalore            3  24.0    Male
# 6     Bachelors         2015  New Delhi            3  40.0    Male
# ...         ...          ...        ...          ...   ...     ...
# 4646  Bachelors         2013  Bangalore            3  27.0  Female
# 4648  Bachelors         2013  Bangalore            3  27.0  Female
# 4649    Masters         2013       Pune            2  39.0    Male
# 4650    Masters         2018  New Delhi            3  28.0    Male
# 4651  Bachelors         2012  Bangalore            3  32.0    Male
#
#      EverBenched  ExperienceInCurrentDomain   Race  LeaveOrNot
# id
# 0             No                          0  white           0
# 1             No                          3  white           1
# 4            Yes                          2  white           1
# 5             No                          0  white           0
# 6             No                          0  white           0
# ...          ...                        ...    ...         ...
# 4646          No                          3  white           0
# 4648          No                          4  black           0
# 4649          No                          2  black           1
# 4650          No                          5  white           1
# 4651         Yes                          2  white           0
#
# [3722 rows x 10 columns]

# %%
# data.info()
# data.isnull().sum()
# data[data.isna().any(axis=1)]

# %% [markdown]
# ## Pipline

# %%
# def drop_col(df):
#   clean_df = df.drop('Unnamed: 0', axis=1)
#   return clean_df

# func_drop_col = FunctionTransformer(drop_col)


NUM_COLS = ['JoiningYear', 'Age', 'ExperienceInCurrentDomain']
CAT_COLS = ['Education', 'City', 'PaymentTier', 'Gender', 'EverBenched', 'Race']

numeric_transformer = Pipeline(steps=[('imputer_num', SimpleImputer(strategy="mean")),
                                      ('scaler', StandardScaler())])


categorical_transformer = Pipeline(steps=[('imputer_cat', SimpleImputer(strategy="most_frequent")),
                                          ('onehot', OneHotEncoder())])

# Combine transformers using ColumnTransformer
column_transformer = ColumnTransformer(transformers=[('num', numeric_transformer, NUM_COLS),
                                                     ('cat', categorical_transformer, CAT_COLS)])

# The final pipeline
preprocess_pipeline = Pipeline(steps=[('col_transformer', column_transformer),
                                     ])
                                  
preprocess_pipeline
# Out:
# Pipeline(steps=[('col_transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['JoiningYear', 'Age',
#                                                    'ExperienceInCurrentDomain']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_cat',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder())]),
#                                                   ['Education', 'City',
#                                                    'PaymentTier', 'Gender',
#                                                    'EverBenched', 'Race'])]))])

# %%
# sm = SMOTE(random_state=42)
# X_train, Y_train = sm.fit_resample(X_train, Y_train)

# %%
prepared_train = preprocess_pipeline.fit_transform(data)
df = pd.DataFrame(prepared_train)

# %% [markdown]
# ## **Decision Tree Classifier**

# %%
dt_clf = DecisionTreeClassifier(random_state=42)

dt_pipeline = Pipeline([('trans_pipeline', preprocess_pipeline),
                        ('dt', dt_clf)])

# applying grid search
params = {'dt__max_depth': [10,25,50,100],
          'dt__min_samples_leaf':[5,10,20,50],
          'dt__min_samples_split':[15,20,50,100]}

gs = GridSearchCV(dt_pipeline, param_grid=params, cv=10, scoring='f1')

gs.fit(X_train, y_train)

best_dt_clf = gs.best_estimator_
best_params = gs.best_params_
best_f1_score = gs.best_score_

print("best f1 score:", best_f1_score)
print("Best Parameters:", best_params)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 13
#       7 params = {'dt__max_depth': [10,25,50,100],
#       8           'dt__min_samples_leaf':[5,10,20,50],
#       9           'dt__min_samples_split':[15,20,50,100]}
#      11 gs = GridSearchCV(dt_pipeline, param_grid=params, cv=10, scoring='f1')
# ---> 13 gs.fit(X_train, y_train)
#      15 best_dt_clf = gs.best_estimator_
#      16 best_params = gs.best_params_
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1419, in GridSearchCV._run_search(self, evaluate_candidates)
#    1417 def _run_search(self, evaluate_candidates):
#    1418     """Search all candidates in param_grid"""
# -> 1419     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     868 elif len(out) != n_candidates * n_splits:
#     869     raise ValueError(
#     870         "cv.split and cv.get_n_splits returned "
#     871         "inconsistent results. Expected {} "
#     872         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     873     )
# --> 875 _warn_or_raise_about_fit_failures(out, self.error_score)
#     877 # For callable self.scoring, the return type is only know after
#     878 # calling. If the return type is a dictionary, the error scores
#     879 # can now be inserted with the correct key. The type checking
#     880 # of out will be done in `_insert_error_scores`.
#     881 if callable(self.scoring):
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:414, in _warn_or_raise_about_fit_failures(results, error_score)
#     407 if num_failed_fits == num_fits:
#     408     all_fits_failed_message = (
#     409         f"\nAll the {num_fits} fits failed.\n"
#     410         "It is very likely that your model is misconfigured.\n"
#     411         "You can try to debug the error by setting error_score='raise'.\n\n"
#     412         f"Below are more details about the failures:\n{fit_errors_summary}"
#     413     )
# --> 414     raise ValueError(all_fits_failed_message)
#     416 else:
#     417     some_fits_failed_message = (
#     418         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     419         "The score on these train-test partitions for these parameters"
#    (...)
#     423         f"Below are more details about the failures:\n{fit_errors_summary}"
#     424     )
#
# ValueError:
# All the 640 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 640 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shaha\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\shaha\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shaha\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 416, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\shaha\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 350, in _fit
#     self._validate_steps()
#   File "C:\Users\shaha\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 234, in _validate_steps
#     raise TypeError(
# TypeError: All intermediate steps should be transformers and implement fit and transform or be the string 'passthrough' 'Pipeline(steps=[('col_transformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer_num',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['JoiningYear', 'Age',
#                                                    'ExperienceInCurrentDomain']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer_cat',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder())]),
#                                                   ['Education', 'City',
#                                                    'PaymentTier', 'Gender',
#                                                    'EverBenched', 'Race'])])),
#                 ('smote', SMOTE(random_state=42))])' (type <class 'sklearn.pipeline.Pipeline'>) doesn't

# %%
# feature importance

# best_clf = best_dt_clf.named_steps['dt']

# feature_importances = pd.Series(best_clf.feature_importances_) #, index=X_train.columns)

# sort_features = feature_importances.sort_values(ascending=False)
# sort_features

# %%
# Make predictions using the best estimator
y_pred = best_dt_clf.predict(X_test)

# Evaluate the model using confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4, 2))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Not Leave', 'Leave'], yticklabels=['Not Leave', 'Leave'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
class_report = classification_report(y_test, y_pred)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       493
#            1       0.81      0.66      0.73       252
#
#     accuracy                           0.83       745
#    macro avg       0.82      0.79      0.80       745
# weighted avg       0.83      0.83      0.83       745

# %% [markdown]
# ## Ada Boost Classifier

# %%
dt_clf = DecisionTreeClassifier(max_depth= 10, min_samples_leaf= 10, min_samples_split= 15)
adb_clf = AdaBoostClassifier(estimator = dt_clf)

adb_pipeline = Pipeline([('trans_pipeline', preprocess_pipeline),
                        ('adb', adb_clf)])

# applying grid search
params = {'adb__n_estimators': [10,50,100],
          'adb__learning_rate':[0.1,0.5,1]}

gs = GridSearchCV(adb_pipeline, param_grid=params, cv=10, scoring='f1')

gs.fit(X_train, y_train)

best_ada_clf = gs.best_estimator_
best_params = gs.best_params_
best_f1_score = gs.best_score_

print("best f1 score:", best_f1_score)
print("Best Parameters:", best_params)
# Out:
# best f1 score: 0.7290981716644238
# Best Parameters: {'adb__learning_rate': 0.1, 'adb__n_estimators': 10}

# %%
# Illustrative of the probability to leave or not

y_proba_dt = best_dt_clf.predict_proba(X)

leave_probs = pd.DataFrame(y_proba_dt,
                         columns=[f'P({x})' for x in best_dt_clf.classes_],
                         index=data.index)
data_joined = data.join(leave_probs)

df = {"p":data_joined["P(1)"].tolist(),
      "LeaveOrNot" :data_joined['LeaveOrNot']};

ax = sns.histplot(df, x="p", hue="LeaveOrNot",bins=100, element="step")

# %% [markdown]
# ## **Random Forest**

# %%
rf_clf = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')

# Modify the pipeline to use the RandomForestClassifier
rf_pipeline = Pipeline([('trans_pipeline', preprocess_pipeline),
                        ('rf', rf_clf)])

# Grid search parameters for the Random Forest
params_rf = {'rf__n_estimators': [50, 100, 200],
             'rf__max_depth': [10,25,50],
             'rf__min_samples_leaf':[5,10,20],
             'rf__min_samples_split':[15,20,50]}

# Grid search with the Random Forest pipeline
gs_rf = GridSearchCV(rf_pipeline, param_grid=params_rf, cv=10, scoring='f1')
gs_rf.fit(X_train, y_train)

# Best Random Forest model
best_rf_clf = gs_rf.best_estimator_
best_rf_params = gs_rf.best_params_
best_f1_score = gs_rf.best_score_

print("best f1 score:", best_f1_score)
print("Best Parameters:", best_rf_params)
# Out:
# best f1 score: 0.7534946104410263
# Best Parameters: {'rf__max_depth': 25, 'rf__min_samples_leaf': 5, 'rf__min_samples_split': 15, 'rf__n_estimators': 200}

# %%
# Make predictions using the best estimator
y_pred = best_rf_clf.predict(X_test)

# %% [markdown]
# ## XG Boost Classifier

# %%
xgb_clf = xgb.XGBClassifier(objective="multi:softmax", num_class=3, random_state=42)

# Modify the pipeline to use the XGBClassifier
xgb_pipeline = Pipeline([('trans_pipeline', preprocess_pipeline),
                        ('xgb', xgb_clf)])

# Grid search parameters for the Random Forest
params_xgb = {'xgb__learning_rate': [0.01, 0.1, 1],
             'xgb__max_depth': [3,5,10]}

gs_xgb = GridSearchCV(xgb_pipeline, param_grid=params_xgb, cv=10, scoring='f1')

# Train the classifier
gs_xgb.fit(X_train, y_train)

# Best model
best_xgb_clf = gs_xgb.best_estimator_
best_xgb_params = gs_xgb.best_params_
best_f1_score = gs_xgb.best_score_

print("best f1 score:", best_f1_score)
print("Best Parameters:", best_xgb_params)

# Make predictions on the test set
#y_pred = xgb_clf.predict(X_test)
# Out:
# best f1 score: 0.7511836612244511
# Best Parameters: {'xgb__learning_rate': 0.1, 'xgb__max_depth': 5}

# %% [markdown]
# ## **Logistic Regression Model**

# %%
# C= Regularization Strength. a large 'C' means you want a smoother curve that captures
# the general trend without fitting each point precisely
# tol= Tolerance for Stopping Criteria. A larger 'tol' means you're willing to stop
# when you are reasonably close, even if you haven't found the absolute best solution.

lr_model = LogisticRegression(class_weight='balanced')

lr_pipeline = Pipeline([('trans_pipeline', preprocess_pipeline),
                        ('logistic_regression', lr_model)])


lr_params = {'logistic_regression__C': [1, 5, 10],
             'logistic_regression__tol': [0.001, 0.0001, 0.00001]}


gs = GridSearchCV(lr_pipeline, param_grid=lr_params, cv=20, scoring='f1')

gs.fit(X_train, y_train)

# the best model
best_lr_clf = gs.best_estimator_
f1_score = gs.best_score_
best_params = gs.best_params_

print("best f1 score:", f1_score)
print("Best Parameters:", best_params)
# Out:
# best f1 score: 0.6040211640418366
# Best Parameters: {'logistic_regression__C': 5, 'logistic_regression__tol': 0.001}

# %%
# Evaluate the model using confusion matrix. the predictions using the best estimator
y_pred = best_lr_clf.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(4, 2))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Not Leave', 'Leave'], yticklabels=['Not Leave', 'Leave'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
class_report = classification_report(y_test, y_pred)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.76      0.78       493
#            1       0.56      0.60      0.58       252
#
#     accuracy                           0.71       745
#    macro avg       0.68      0.68      0.68       745
# weighted avg       0.71      0.71      0.71       745

# %%
# Illustrative of the probability to leave or not

y_proba_lr = best_lr_clf.predict_proba(X)

leave_probs = pd.DataFrame(y_proba_lr,
                         columns=[f'P({x})' for x in best_lr_clf.classes_],
                         index=data.index)
data_joined = data.join(leave_probs)

df = {"p":data_joined["P(1)"].tolist(),
      "LeaveOrNot" :data_joined['LeaveOrNot']};

ax = sns.histplot(df, x="p", hue="LeaveOrNot",bins=100, element="step")

# %% [markdown]
# ## ROC - AUC

# %%
# Calculate predicted probabilities for the "1" class (leave)
y_proba_dt = best_dt_clf.predict_proba(X_test)[:, 1]
y_proba_rf = best_rf_clf.predict_proba(X_test)[:, 1]
y_proba_lr = best_lr_clf.predict_proba(X_test)[:, 1]
y_proba_ada = best_ada_clf.predict_proba(X_test)[:, 1]
y_proba_xgb = best_xgb_clf.predict_proba(X_test)[:, 1]

# AUC
auc_dt = roc_auc_score(y_test, y_proba_dt)
auc_rf = roc_auc_score(y_test, y_proba_rf)
auc_lr = roc_auc_score(y_test, y_proba_lr)
auc_ada = roc_auc_score(y_test, y_proba_ada)
auc_xgb = roc_auc_score(y_test, y_proba_xgb)

# ROC Curve
dt_fpr, dt_tpr, dt_thresholds = roc_curve(y_test, y_proba_dt)
rf_fpr, rf_tpr, rf_thresholds = roc_curve(y_test, y_proba_rf)
lr_fpr, lr_tpr, lr_thresholds = roc_curve(y_test, y_proba_lr)
ada_fpr, ada_tpr, ada_thresholds = roc_curve(y_test, y_proba_ada)
xgb_fpr, xgb_tpr, xgb_thresholds = roc_curve(y_test, y_proba_xgb)

# Plot ROC Curve
plt.figure(figsize=(10, 8))
plt.plot(dt_fpr, dt_tpr, label=f'Decision Tree (AUC = {auc_dt:.2f})')
plt.plot(rf_fpr, rf_tpr, label=f'Random Forest (AUC = {auc_rf:.2f})')
plt.plot(lr_fpr, lr_tpr, label=f'Logistic Regression (AUC = {auc_lr:.2f})')
plt.plot(ada_fpr, ada_tpr, label=f'Ada Boost (AUC = {auc_ada:.2f})')
plt.plot(xgb_fpr, xgb_tpr, label=f'XG Boost (AUC = {auc_xgb:.2f})')


plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

print("AUC - Decision Tree:", auc_dt)
print("AUC - Random Forest:", auc_rf)
print("AUC - Logistic Regression:", auc_lr)
print("AUC - Ada Boost:", auc_ada)
print("AUC - XG Boost:", auc_xgb)
# Out:
# AUC - Decision Tree: 0.8648660613670756
# AUC - Random Forest: 0.8665040728935252
# AUC - Logistic Regression: 0.7327666698863453
# AUC - Ada Boost: 0.8666610322289835
# AUC - XG Boost: 0.8656387842493319

# %% [markdown]
# ## Voting

# %%
# Soft Voting- The predicted class is the one with the highest summed probability across all classifiers.
# the classifier sums up the predicted probabilities for each class from individual classifiers and selects the class
# with the highest sum.

#('best_dt_clf', best_dt_clf)
#('lr_pipeline', lr_pipeline)
#('best_rf_clf', best_rf_clf)
#('best_xgb_clf', best_xgb_clf)

voting_clf = VotingClassifier(estimators= [('best_dt_clf', best_dt_clf), ('best_rf_clf', best_rf_clf)], voting= 'soft')

voting_clf.fit(X_train.iloc[1:1000], y_train.iloc[1:1000])
# Out:
# VotingClassifier(estimators=[('best_dt_clf',
#                               Pipeline(steps=[('trans_pipeline',
#                                                Pipeline(steps=[('drop_id',
#                                                                 FunctionTransformer(func=<function drop_col at 0x0000017663256160>)),
#                                                                ('col_transformer',
#                                                                 ColumnTransformer(transformers=[('num',
#                                                                                                  Pipeline(steps=[('imputer_num',
#                                                                                                                   SimpleImputer()),
#                                                                                                                  ('scaler',
#                                                                                                                   StandardScaler())]),
#                                                                                                  ['JoiningYear',
#                                                                                                   'Age',
#                                                                                                   'ExperienceInCurrentDo...
#                                                                                                   'ExperienceInCurrentDomain']),
#                                                                                                 ('cat',
#                                                                                                  Pipeline(steps=[('imputer_cat',
#                                                                                                                   SimpleImputer(strategy='most_frequent')),
#                                                                                                                  ('onehot',
#                                                                                                                   OneHotEncoder())]),
#                                                                                                  ['Education',
#                                                                                                   'City',
#                                                                                                   'PaymentTier',
#                                                                                                   'Gender',
#                                                                                                   'EverBenched',
#                                                                                                   'Race'])]))])),
#                                               ('rf',
#                                                RandomForestClassifier(class_weight='balanced',
#                                                                       max_depth=25,
#                                                                       min_samples_leaf=5,
#                                                                       min_samples_split=15,
#                                                                       n_estimators=200,
#                                                                       random_state=42))]))],
#                  voting='soft')

# %%
accuracy = voting_clf.score(X_test, y_test)
accuracy
# Out:
# 0.8308724832214766

# %%
y_pred_vote = voting_clf.predict(X_test)
# f1_score_voting = f1_score(y_test,y_pred_vote)
# print("F1 Score:", f1_score_voting)
y_pred_vote
